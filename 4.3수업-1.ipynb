# %%
i = 0
while i<5:
    print('welcome to everyone!!')
    i+=1
# Out:
# welcome to everyone!!
# welcome to everyone!!
# welcome to everyone!!
# welcome to everyone!!
# welcome to everyone!!

# %%
for i in range (5):
    print('welcome')
# Out:
# welcome
# welcome
# welcome
# welcome
# welcome

# %%
isum = 0
n_list = [0,2,5,10]
for i in n_list:
    isum+=i
print(isum)
# Out:
# 17

# %%
isum = 0
n_list = [0,2,5,10]
i = 0
while i<4:
    isum += n_list[i]  # a+=b   = a+b
    i+=1
print(isum)
# Out:
# 17

# %%
selected = None
while selected not in ['가위','바위','보']:   # 가위 바위 보 를 안치면 true > input 출력 
    selected = input ('가위,바위,보 중에서 선택하세요>')
print ('선택한 값은:', selected)
# Out:
# 가위,바위,보 중에서 선택하세요> 묵
# 가위,바위,보 중에서 선택하세요> 묵
# 가위,바위,보 중에서 선택하세요> 묵
# 가위,바위,보 중에서 선택하세요> 찌
# 가위,바위,보 중에서 선택하세요> 빠
# 가위,바위,보 중에서 선택하세요> 가위
# 선택한 값은: 가위

# %%
st = 'programing'

for ch in st:
    if ch in ['a','e','i','o','u']:
        break
    print(ch)
print ('The end')
# Out:
# p
# r
# The end
