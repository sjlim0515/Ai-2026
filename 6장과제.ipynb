# %%
capital_dic = {'korea':'seoul', 'china':'beijing', 'usa':'washington dc'}
print (capital_dic['korea'])
print (capital_dic['china'])
print (capital_dic['usa'])

fruits_dic = {'apple':5000, 'banana':4000, 'grape':5300,'melon':6500}
a =input("과일을 입력하세요: ")
print('{}의 가격은{}입니다.'.format(a,fruits_dic[a]))
# Out:
# seoul
# beijing
# washington dc
# 과일을 입력하세요:  apple
# apple의 가격은5000입니다.

# %%
person = {'이름':'홍길동','나이':'26'}
person['특기'] = '분신술'
print (person)
person['아버지'] = '홍판서'
print (person)
del person['나이']
print (person)
# Out:
# {'이름': '홍길동', '나이': '26', '특기': '분신술'}
# {'이름': '홍길동', '나이': '26', '특기': '분신술', '아버지': '홍판서'}
# {'이름': '홍길동', '특기': '분신술', '아버지': '홍판서'}

# %%
capital_dic = {'korea':'seoul', 'china':'beijing', 'usa':'washington dc'}
print ('korea' in capital_dic)
print ('china' in capital_dic)
print ('indoneia' in capital_dic)
print ('beijing' in capital_dic)
# Out:
# True
# True
# False
# False

# %%
fruits_dic = {'apple':6000, 'banana':3000, 'orange':7000,'melon':3000}

print (fruits_dic.keys())
print(fruits_dic.values())
print(fruits_dic.pop('apple'))
print (fruits_dic.clear())
# Out:
# dict_keys(['apple', 'banana', 'orange', 'melon'])
# dict_values([6000, 3000, 7000, 3000])
# 6000
# None

# %%
fruits_dic = {'apple':6000, 'banana':5000, 'orange':4000,'melon':3000}
print(list(fruits_dic.keys()))
print(list(fruits_dic.values()))
print(len(fruits_dic))

if 'apple' in fruits_dic:
    print('apple is in fruits_dic.')
else:
    print('apple is not in fruits_dic.')

if 'mango' in fruits_dic:
    print('mango is in fruits_dic.')
else:
    print('mango is not in fruits_dic.')
# Out:
# ['apple', 'banana', 'orange', 'melon']
# [6000, 5000, 4000, 3000]
# 4
# apple is in fruits_dic.
# mango is not in fruits_dic.

# %%
the_day = (1919, 3, 1)
year,month,day = the_day
print (year,'년',month,'월',day,'일은 삼일절입니다')

numbers = [10, 20, 30]
c, b, a = tuple(numbers)
print(a, b, c)
# Out:
# 1919 년 3 월 1 일은 삼일절입니다
# 30 20 10

# %%
person = (2019001, '홍길동', 179)
print(person)

# person[0] = 2019003 = typeerror 발생

person = (2019001, '홍길동', 179)
person_list = list(person)
person_list[0] = 2020003
person = tuple(person_list)
print(person)
# Out:
# (2019001, '홍길동', 179)
# (2020003, '홍길동', 179)

# %%
def square(x, y):
    return x**2, y**2

x= 10
y = 20
x_sq, y_sq = square(x,y)
print('{} 제곱 = {},{}제곱 = {}'.format(x, x_sq, y, y_sq))

a= (10,20,30)
b = (40,50,60)
print(a+b)

print('Hello'*3)
print(('Hello',)*3)
# Out:
# 10 제곱 = 100,20제곱 = 400
# (10, 20, 30, 40, 50, 60)
# HelloHelloHello
# ('Hello', 'Hello', 'Hello')

# %%
lst = ['apple', 'mango', 'banana']
s1 = set(lst)
print(s1)

greet = 'Good afternoon'
s2 = set(greet)
print(s2)
# Out:
# {'mango', 'apple', 'banana'}
# {'G', 'r', 't', 'n', 'o', 'd', 'a', 'e', 'f', ' '}

# %%
s1={10,20,30,40}
s2={30,40,50,60,70}

print (s1 | s2)
print (s1 & s2)
print (s1 - s2)
print (s1 ^ s2)
print (s1.issubset(s2))
print(s1.issuperset(s2))
print (s1.isdisjoint(s2))
# Out:
# {70, 40, 10, 50, 20, 60, 30}
# {40, 30}
# {10, 20}
# {50, 20, 70, 10, 60}
# False
# False
# False
