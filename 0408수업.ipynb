# %%
person = {'이름': '홍길동','나이':26,'몸무게': 82} #key = 이름,나이,몸무게
print (person ['이름'])
print (person ['나이'])
print (person ['몸무게'])
# Out:
# 홍길동
# 26
# 82

# %%
students = {2019001: '이순신', 2019002: '김유신', 2019003: '강감찬'}
print (students [2019003])
print (students [2019002])
print (students [2019001])
# Out:
# 강감찬
# 김유신
# 이순신

# %%
person = {'이름': '홍길동','나이':26,'몸무게': 82}
person ['직업'] = '율도국의 왕' # 딕셔너리 항목에 직업 추가 
person['나이'] = 27 # 나이 26인 사실을 27로 수정
person
# Out:
# {'이름': '홍길동', '나이': 27, '몸무게': 82, '직업': '율도국의 왕'}

# %%
person = {'이름': '홍길동','나이':26,'몸무게': 82}
del person ['나이'] # del 통해 항목 삭제
person ['나이'] # 삭제돼서 keyerror
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
#       1 person = {'이름': '홍길동','나이':26,'몸무게': 82}
#       2 del person ['나이'] # del 통해 항목 삭제
# ----> 3 person ['나이']
#
# KeyError: '나이'

# %%
students = {2019001: '이순신', 2019002: '김유신', 2019003: '강감찬'} # 과제 전화번호부 만들기 참고 (아래 코딩도 전부)
a = int(input('입력하세요:'))
if a is a>2019000:
    print (students [a])
print (students.keys())
print (students.values())
print (students.items())
# Out:
# 입력하세요: 2019002
# 김유신
# dict_keys([2019001, 2019002, 2019003])
# dict_values(['이순신', '김유신', '강감찬'])
# dict_items([(2019001, '이순신'), (2019002, '김유신'), (2019003, '강감찬')])

# %%
students = {2019001: '이순신', 2019002: '김유신', 2019003: '강감찬'}
students.keys()
# Out:
# dict_keys([2019001, 2019002, 2019003])

# %%
person = {'이름': '홍길동','나이':26,'몸무게': 82}
person['국적'] = '대한민국'

for key in person:
    print('{}:{}'.format(key,person[key])) #format ( key, value ) 뜻함
# Out:
# 이름:홍길동
# 나이:26
# 몸무게:82
# 국적:대한민국

# %%
tuple = (1,2,3,4)
tuple[0] = 1  # 에러 생김 ,,,, tuple은 리스트와 다르게 한번 지정되면 바꾸지 못함 
print (tuple[0])
print (tuple[3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 tuple = (1,2,3,4)
# ----> 2 tuple[0] = 1
#       3 print (tuple[0])
#       4 print (tuple[3])
#
# TypeError: 'tuple' object does not support item assignment

# %%
def plusminus (a1,a2):
    return a1+a2, a1-a2

output = plusminus(10,2)
print(type(output))

output_list = list(output) # tuple > list 로 변환 
print (type(output_list))
# Out:
# <class 'tuple'>
# <class 'list'>

# %%
a = (1,2) # 튜플 패킹
a[0]
# Out:
# 1

# %%
c = (3,4) #패킹
d,e=c #언패킹
print (d)
print (e)
# Out:
# 3
# 4

# %%
a= 100 #swap 하는 법 
b= 200
print ('Before swap: ' , a,b)
a,b=b,a
print ('After swap' , a,b)
# Out:
# Before swap:  100 200
# After swap 200 100

# %%
# 짐합
set1={0,1,2,3,4,5,5}
print(set1) # 집합은 중복되는값 출력 x
# Out:
# {0, 1, 2, 3, 4, 5}

# %%
set1={0,5,2,2,4,1}
print(set1) #순서대로 + 중복없이 출력
# Out:
# {0, 1, 2, 4, 5}

# %%
aset={1,2,3,4}
bset={2,4,6,7}
#다 같은 내용
cset = aset.union(bset)
cset = aset|bset #(shift \)
cset = bset$aset
cset= bset.union(aset)

#같은 내용
cset = bset - aset
cset = aset.diffrence(bset)
cset = bset- aset 
print(cset)
# Out:
# {1, 2, 3, 4, 6, 7}
