# %%
myString = "apple"
for ch in myString:
    print(ch)

listString = list (myString)
print (listString[-1])
# Out:
# a
# p
# p
# l
# e
# e

# %%
a_list = ['a','b','c','d','e']
a_list.append('f') #append 통해 list에 f 추가  
a_list
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
n_list = [10,20,30,40]
n_list.append(50)
n_list
# Out:
# [10, 20, 30, 40, 50]

# %%
b_list = [11,22,33,44,55]
b_list.remove(44) #remove 통해 list 44 삭제
b_list
# Out:
# [11, 22, 33, 55]

# %%
b_list = [11,22,33,44,55]
del b_list[3] # list 3번항목 삭제
b_list
# Out:
# [11, 22, 33, 55]

# %%
a_list = [11,22,33,44,55,66]
a= a_list.pop() #pop은 output 존재..?
print (a)
print (a_list) # 젤 뒤에게 삭제된상태로 프린트됨 ,, 
b= a_list.pop()
print (b)
print(a_list) # pop을 통해 젤 뒤부터 하나씩 제거
# Out:
# 66
# [11, 22, 33, 44, 55]
# 55
# [11, 22, 33, 44]

# %%
a_list = [10,20,30,40]
10 in a_list # list에 10이 있는가?
10 not in a_list # list 에 10이 없는가?
# Out:
# False

# %%
list1 = [10,20,30,40]
min(list1) # 제일 작은수
max(list1) # 제일 큰 수
sum(list1) #리스트 합
# Out:
# 100

# %%
list1 = [20,10,30,50,40]
list1.sort() # sort 통해서 순서대로 정렬
list1
# Out:
# [10, 20, 30, 40, 50]

# %%
list1=[10,40,30,50,20]
list2=sorted(list1)
print (list1)
print (list2)
# Out:
# [10, 40, 30, 50, 20]
# [10, 20, 30, 40, 50]
