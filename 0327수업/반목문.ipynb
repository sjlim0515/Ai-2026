# %%
for i in range(5):
    print(i,end='\n')
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(0,5):
    print(i,end=' ') #end = ' ' 하면 줄 변환해줌 ~ 없으면 기본적으로 \n (줄바꿈기호) 가 들어감
# Out:
# 0 1 2 3 4

# %%
for i in range(2,5):
    print (i, end = ' ')
print ()
# Out:
# 2 3 4

# %%
for i in range (0,10,2):
    print(i, end=' ')
# Out:
# 0 2 4 6 8
