# %%
i = 0
while i<5:
    print('welcome to everyone!!')
    i+=1
# Out:
# welcome to everyone!!
# welcome to everyone!!
# welcome to everyone!!
# welcome to everyone!!
# welcome to everyone!!

# %%
for i in range (5):
    print('welcome')
# Out:
# welcome
# welcome
# welcome
# welcome
# welcome

# %%
isum = 0
n_list = [0,2,5,10]
for i in n_list:
    isum+=i
print(isum)
# Out:
# 17

# %%
isum = 0
n_list = [0,2,5,10]
i = 0
while i<4:
    isum += n_list[i]
    i+=1
print(isum)
# Out:
# 17
